# %%
import pandas as pd
from google.colab import drive 
drive.mount('/content/MyGoogleDrive')

df = pd.read_csv('https://data.epa.gov.tw/api/v2/aqx_p_322?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=monitordate%20desc&format=CSV')
o_filepath = 'https://drive.google.com/drive/search?q=owner:me%20(type:application/vnd.google.colaboratory%20||%20type:application/vnd.google.colab)'
filename = 'PM2.5.csv'
df.to_csv(o_filepath + filename)
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).
