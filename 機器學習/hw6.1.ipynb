# %%
import pandas as pd
from google.colab import drive 
drive.mount('/content/MyGoogleDrive')
# Out:
# Mounted at /content/MyGoogleDrive

# %%
df = pd.read_csv('/content/MyGoogleDrive/MyDrive/train.csv')
# 使用.head()觀察前5筆資料
df.head()

# 使用.shape觀察資料的列數和欄數
df.shape

# 使用.describe()觀察資料的統計數據
df.describe()

# 檢查有多少遺失值
df.isna().sum()

# # 計算缺失值的比例
# df.isnull().sum() / df.isnull().count() * 100

# # 將'Age'遺失值填補為平均數
# df['Age'] = df['Age'].fillna(df['Age'].mean())

# # 將Embarked遺失值填補為最常出現的值
# df['Embarked'] = df['Embarked'].fillna('S')

# # 刪除Cabin欄位
# df = df.drop('Cabin', axis=1)

# # 檢查是否有重複資料
# df[df.duplicated()]

# # 將性別欄位轉換為數字
# s = {'female': 0, 'male': 1}
# df['Sex'] = df['Sex'].map(s)

# # 將Embarked欄位轉換為數字
# e = {'S': 0, 'C': 1, 'Q': 2}
# df['Embarked'] = df['Embarked'].map(e)

# # 使用圖表簡單觀察
# import matplotlib.pyplot as plt
# df
# # # 觀察性別在這場災難中的存活狀況
# # df.groupby(['Sex', 'Survived'])['PassengerId'].count().plot(kind='bar', rot=1)

# # # 觀察艙等在這場災難中的存活狀況
# # ps = df.groupby(['Pclass', 'Survived'])['PassengerId'].count() / df.groupby(['Pclass'])['PassengerId'].count() * 100
# # ps.plot(kind='bar', rot=1)

# # # 觀察碼頭在這場災難中的存活狀況
# # es = df.groupby(['Embarked', 'Survived'])['PassengerId'].count() / df.groupby(['Embarked'])['PassengerId'].count() * 100
# # es.plot(kind='bar', rot=1)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
