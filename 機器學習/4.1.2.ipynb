# %%
from google.colab import drive
drive.mount('/content/MyGoogleDrive')
import pandas as pd
# Out:
# Drive already mounted at /content/MyGoogleDrive; to attempt to forcibly remount, call drive.mount("/content/MyGoogleDrive", force_remount=True).

# %%
df = pd.read_csv('/content/MyGoogleDrive/MyDrive/Ch04/學生成績檔-4-1.2.csv')
filter = df['第1次平時考'] == -1 
df[filter]
i = df[filter].index 
df = df.drop(i, axis = 0) 
df1 = df.drop(2)
df1.head()
df1 = df.reset_index()
df1.head()
o_filepath = '/content/MyGoogleDrive/MyDrive/Colab Notebooks/機器學習/'
filename = '學生成績檔-4-1.2-ANS.csv' 
df.to_csv(o_filepath + filename, index=False)
